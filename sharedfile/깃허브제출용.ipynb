# %% [markdown]
# # 구름edu

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
from tqdm import tqdm

# %%
### 구름edu-강의명, 가격, 강사, 평점, url

# %%
title_list = [] #강의명
price_list = [] #가격
teacher_list = [] #강사
rating_list= [] #평점
url_list = [] #url

for i in tqdm(range(1,21)):
    #사이트 페이지별
    url1 = "https://edu.goorm.io/category/programming?page="+str(i)+"&sort=newest"
    driver = wb.Chrome()
    driver.get(url1)
    soup = bs(driver.page_source,"lxml")
    time.sleep(1)
    #각 요소 추출
    price = soup.select("div.RfUd-z._1AV9t8.card-footer > div > span._3vh60A")
    title = soup.select("div > div.obzTi8 > div.kV2LiJ")
    teacher = soup.select('._3SzRPA > .xaJHLa')
    rating = soup.select('._2KWt9f._3SwFuE')
    url = soup.select("._1xnzzp")
    time.sleep(1)
    
    #각 요소 리스트에 저장
    for i in range(len(title)):
        title_list.append(title[i].text)
        price_list.append(price[i].text)
        teacher_list.append(teacher[i].text)
        rating_list.append(rating[i].text)
        url_list.append('https://edu.goorm.io'+url[i]['href'])
    time.sleep(1)

# %% [markdown]
# ### 카테고리

# %%
cate_list = []

for i in tqdm(range(1,21)):
    for k in tqdm(range(1,21)):
    #각 페이지별
    url1 = "https://edu.goorm.io/category/programming?page="+str(i)+"&sort=newest"
    driver = wb.Chrome()
    driver.get(url1)
    soup = bs(driver.page_source,"lxml")
    time.sleep(1)
    #각 강의 클릭
    btn = driver.find_element_by_css_selector('div.Aj2j_L > div:nth-child('+str(k)+')>a')
    btn.click()
    time.sleep(3)
    soup = bs(driver.page_source,"lxml")
    #카테고리(cate) 추출
    cate = soup.select('div:nth-child(2) > div._2yM5um')
    #카테고리 저장
    for j in range(len(cate)):
        cate_list.append(cate[j].text)
    driver.close()

# %%
print(len(title_list))
print(len(price_list))
print(len(teacher_list))
print(len(rating_list))
print(len(url_list))
print(len(cate_list))

# %% [markdown]
# ### 리뷰

# %%
goorum_review_list= []

for i in tqdm(range(2,3)):
    for k in tqdm(range(1,21)):
        #창열기
        url1 = "https://edu.goorm.io/category/programming?page="+str(i)+"&sort=newest"
        driver = wb.Chrome()
        driver.get(url1)
        soup = bs(driver.page_source,"lxml")
        #클릭할 항목 수 변동
        btn = driver.find_element_by_css_selector('div.Aj2j_L > div:nth-child('+str(k)+')>a')
        btn.click()
        time.sleep(3)
        soup = bs(driver.page_source,"lxml")
        time.sleep(1)
        #리뷰를 한꺼번에 모아줄 리스트 초기화
        review_list = []
        #리뷰 3개 넣기
        for j in range(2,5):
            review = soup.select('#tabContents_4 > div > ul > li:nth-child('+str(j)+') > div > div._21ON4p.card-body > p')
        #리뷰 3개를 한꺼번에 모아줄 review_list에 넣기
        for a in range(len(review)):
            review_list.append(review[a].text)
        goorum_review_list.append(review_list)
        driver.close()

# %% [markdown]
# # 클래스101

# %%
#빈 리스트
title_list = []
dump_list = []
teacher_list = []
rating_list = []
url_list = []

# %%
for i in range(1,3):
#페이지의 정보 가져오기
    url1 = "https://class101.net/search?category=604f1c9756c3676f1ed00397&page="=str(i)+"&sort=recommendOrder"
    driver = wb.Chrome()
    driver.get(url1)
    time.sleep(1)
    soup = bs(driver.page_source,"lxml")
    title = soup.select("div.Card__Title-sc-1esp5o0-4.cMrDHW")
    dump = soup.select(".css-i14ikp")
    teacher = soup.select("div.css-13tgwhv > small")
    url = soup.select('.ProductCardfragment__HoverStyledLink-sc-1cja13i-0.gfCFNQ')
    time.sleep(1)
    for j in range(len(url)):
        title_list.append(title[j].text)
        url_list.append('https://class101.net'+url[j]['href'])
        teacher_list.append(teacher[j].text)
    for k in range(len(dump)):
        dump_list.append(dump[k].text[3:])
    time.sleep(1)

# %% [markdown]
# ### 처음 클릭하면 팝업창이 뜸

# %% [markdown]
# ### div가 두 개, 첫번째는 6개의 li, 두 번째는 24개의 li가 있음

# %% [markdown]
# ### 1페이지

# %%
#첫번째 페이지, 팝업창
class101_num_list = []
class101_review_list = []
review_list = []
class101_cate_list = []

url1 = "https://class101.net/search?category=604f1c9756c3676f1ed00397"
driver = wb.Chrome()
driver.get(url1)
time.sleep(8)
btn = driver.find_element_by_css_selector('ul > li:nth-child(1) > a')
btn.click()
time.sleep(8)
btnclose = driver.find_element_by_css_selector('.ab-close-button')
btnclose.click()
soup = bs(driver.page_source,"lxml")
time.sleep(3)

cate = soup.select_one('.BaseTypography__TextElement-sc-8ucuwh-0.hhRVWr.ProductHeader__Tag-sc-4rgr4k-1.fcfJjr')
num= soup.select_one('dd.KlassSummarySection__DefinitionDescription-lcwqnj-4.jeiEOD')
class101_cate_list.append(cate.text)
class101_num_list.append(num.text)
#리뷰 리스트 초기화
review_list = []
soup = bs(driver.page_source,"lxml")
#리뷰 추출
review = soup.select('.ReviewV2Card__Content-sc-1mma0rc-10.jQJcjX')

#리뷰를 더보기 해야 할 경우, 아닌 경우
if review != None:
    #모은 리뷰들을 하나의 리스트에 저장
    for k in range(len(review)):
        review_list.append(review[k].text)
        #새 리스트에 저장
    class101_review_list.append(review_list)
    #뒤로가기
    driver.back()
    time.sleep(4)
else:      
    print("예외적 상황")
    review_list = []
    #후기 더보기 버튼 클릭
    btn2 = driver.find_element_by_css_selector('#product-view-review > section > div > a:nth-child(8)')
    btn2.click()
    time.sleep(5)
    soup = bs(driver.page_source,"lxml")
    #리뷰 추출
    review = soup.select('.Timer__Day-sc-1mgbdlp-1.bxcQif')
    #모은 리뷰들을 하나의 리스트에 저장
    for k in range(len(review)):
        review_list.append(review[k].text)
    #새 리스트에 저장
    class101_review_list.append(review_list)
    driver.back()
    time.sleep(4)
    driver.back()
    time.sleep(4)

# 첫번째 div -> 1번은 이미 실행
for i in tqdm(range(2,7)):
    # 강의페이지 들어가기
    btn = driver.find_element_by_css_selector('div.GridList__Container-sc-1qd26lc-0.fIyoAK > ul > li:nth-child('+str(i)+') > a')
    btn.click()
    time.sleep(10)
    soup = bs(driver.page_source,"lxml")
    #카테고리
    cate = soup.select_one('.BaseTypography__TextElement-sc-8ucuwh-0.hhRVWr.ProductHeader__Tag-sc-4rgr4k-1.fcfJjr')
    #강의길이
    num = soup.select_one('.KlassSummarySection__DefinitionDescription-lcwqnj-4.jeiEOD')
    class101_cate_list.append(cate.text)
    class101_num_list.append(num.text)
    time.sleep(10)
    #리뷰 리스트 초기화
review_list = []
soup = bs(driver.page_source,"lxml")
#리뷰 추출
review = soup.select('.ReviewV2Card__Content-sc-1mma0rc-10.jQJcjX')

#리뷰를 더보기 해야 할 경우, 아닌 경우
if review != None:
    #모은 리뷰들을 하나의 리스트에 저장
    for k in range(len(review)):
        review_list.append(review[k].text)
    #새 리스트에 저장
    class101_review_list.append(review_list)
    #뒤로가기
    driver.back()
    time.sleep(4)
else:      
    print("예외적 상황")
    review_list = []
    #후기 더보기 버튼 클릭
    btn2 = driver.find_element_by_css_selector('#product-view-review > section > div > a:nth-child(8)')
    btn2.click()
    time.sleep(5)
    soup = bs(driver.page_source,"lxml")
    #리뷰 추출
    review = soup.select('.Timer__Day-sc-1mgbdlp-1.bxcQif')
    #모은 리뷰들을 하나의 리스트에 저장
    for k in range(len(review)):
        review_list.append(review[k].text)
    #새 리스트에 저장
    class101_review_list.append(review_list)
    driver.back()
    time.sleep(4)
    driver.back()
    time.sleep(4)

for i in tqdm(range(1,25)):
    #강의페이지들어가기
    btn = driver.find_element_by_css_selector('div.infinite-scroll-component__outerdiv > div > div:nth-child(1) > ul > li:nth-child('+str(i)+')>a')
    btn.click()
    time.sleep(10)
    soup = bs(driver.page_source,"lxml")
    #카테고리추출
    cate = soup.select_one('.BaseTypography__TextElement-sc-8ucuwh-0.hhRVWr.ProductHeader__Tag-sc-4rgr4k-1.fcfJjr')
    #강의길이추출
    num = soup.select_one('.KlassSummarySection__DefinitionDescription-lcwqnj-4.jeiEOD')
    #추출한 정보 삽입
    class101_cate_list.append(cate.text)
    class101_num_list.append(num.text)
    time.sleep(10)
    #리뷰 리스트 초기화
    review_list = []
    soup = bs(driver.page_source,"lxml")
    #리뷰 추출
    review = soup.select('.ReviewV2Card__Content-sc-1mma0rc-10.jQJcjX')
    if review != None:
        #모은 리뷰들을 하나의 리스트에 저장
        for k in range(len(review)):
            review_list.append(review[k].text)
        #새 리스트에 저장
        class101_review_list.append(review_list)
        #뒤로가기
        driver.back()
            time.sleep(4)
    else:      
        #=====이 부분이 제대로 안됨!!!!!!=======
        print("예외적 상황")
        review_list = []
        #후기 더보기 버튼 클릭
        btn2 = driver.find_element_by_css_selector('#product-view-review > section > div > a:nth-child(8)')
        btn2.click()
        time.sleep(5)
        soup = bs(driver.page_source,"lxml")
        #리뷰 추출
        review = soup.select('.Timer__Day-sc-1mgbdlp-1.bxcQif')
        #모은 리뷰들을 하나의 리스트에 저장
        for k in range(len(review)):
            review_list.append(review[k].text)
        #새 리스트에 저장
        class101_review_list.append(review_list)
        driver.back()
        time.sleep(4)
        driver.back()
        time.sleep(4)

# %% [markdown]
# ### 2페이지(페이지를 미리 실행해야 함)

# %%
#처음 클릭 팝업창 제거
url1 = "https://class101.net/search?category=604f1c9756c3676f1ed00397&page=2&sort=recommendOrder"
driver = wb.Chrome()
driver.get(url1)
time.sleep(8)
btn = driver.find_element_by_css_selector('ul > li:nth-child(1) > a')
btn.click()
time.sleep(8)
btnclose = driver.find_element_by_css_selector('.ab-close-button')
btnclose.click()
soup = bs(driver.page_source,"lxml")
time.sleep(3)

#첫번째 div
for i in tqdm(range(1,7)):
    # 강의페이지 들어가기
    btn = driver.find_element_by_css_selector('div.GridList__Container-sc-1qd26lc-0.fIyoAK > ul > li:nth-child('+str(i)+') > a')
    btn.click()
    time.sleep(10)
    soup = bs(driver.page_source,"lxml")
    #카테고리
    cate = soup.select_one('.BaseTypography__TextElement-sc-8ucuwh-0.hhRVWr.ProductHeader__Tag-sc-4rgr4k-1.fcfJjr')
    #강의길이
    num = soup.select_one('.KlassSummarySection__DefinitionDescription-lcwqnj-4.jeiEOD')
    class101_cate_list.append(cate.text)
    class101_num_list.append(num.text)
    time.sleep(10)
    try:
        review_list = []
        soup = bs(driver.page_source,"lxml")
        review = soup.select('.ReviewV2Card__Content-sc-1mma0rc-10.jQJcjX')
        for k in range(len(review)):
                review_list.append(review[k].text)
        class101_review_list.append(review_list)
        driver.back()
        time.sleep(4)
    except:
        #리뷰 더보기에 들어가야 할 경우
        print("예외리뷰출력")
        review_list = []
        btn2 = driver.find_element_by_css_selector('#product-view-review > section > div > a:nth-child(8)')
        btn2.click()
        time.sleep(5)
        soup = bs(driver.page_source,"lxml")
        review = soup.select('.Timer__Day-sc-1mgbdlp-1.bxcQif')
        for k in range(len(review)):
            review_list.append(review[k].text)
        class101_review_list.append(review_list)
        driver.back()
        time.sleep(1)
        driver.back()
        time.sleep(1)

#두 번째 div
for i in tqdm(range(1,25)):
    #강의페이지들어가기
    btn = driver.find_element_by_css_selector('div.infinite-scroll-component__outerdiv > div > div:nth-child(1) > ul > li:nth-child('+str(i)+')>a')
    btn.click()
    time.sleep(10)
    soup = bs(driver.page_source,"lxml")
    #카테고리추출
    cate = soup.select_one('.BaseTypography__TextElement-sc-8ucuwh-0.hhRVWr.ProductHeader__Tag-sc-4rgr4k-1.fcfJjr')
    #강의길이추출
    num = soup.select_one('.KlassSummarySection__DefinitionDescription-lcwqnj-4.jeiEOD')
    #추출한 정보 삽입
    class101_cate_list.append(cate.text)
    class101_num_list.append(num.text)
    time.sleep(10)
    try:
        #리뷰 리스트 초기화
        review_list = []
        soup = bs(driver.page_source,"lxml")
        #리뷰 추출
        review = soup.select('.ReviewV2Card__Content-sc-1mma0rc-10.jQJcjX')
        #모은 리뷰들을 하나의 리스트에 저장
        for k in range(len(review)):
                review_list.append(review[k].text)
        #새 리스트에 저장
        class101_review_list.append(review_list)
        #뒤로가기
        driver.back()
        time.sleep(4)
    except:
        #=====이 부분이 제대로 안됨!!!!!!=======
        #리뷰 더보기에 들어가야 할 경우
        print("예외리뷰출력")
        review_list = []
        #후기 더보기 버튼 클릭
        btn2 = driver.find_element_by_css_selector('a.LinkBlock-ky5rdu-0 ButtonBase__LinkButton-sc-1lxfn99-3.gXokuE.iFkzVH')
        btn2.click()
        time.sleep(5)
        soup = bs(driver.page_source,"lxml")
        #리뷰 추출
        review = soup.select('.Timer__Day-sc-1mgbdlp-1.bxcQif')
        #모은 리뷰들을 하나의 리스트에 저장
        for k in range(len(review)):
            review_list.append(review[k].text)
        #새 리스트에 저장
        class101_review_list.append(review_list)
        driver.back()
        time.sleep(4)
        driver.back()
        time.sleep(4)

# %% [markdown]
# ### 가격이 없는 2개 때문에 길이 차이(클래스101은 배열이 바뀌기에 인덱스 숫자변동필요)

# %%
print(len(title_list))
print(len(dump_list))
print(len(url_list))
print(len(teacher_list))

# %%
print(title_list[39])
dump_list.insert(39,'0원')

# %%
print(title_list[45])
dump_list.insert(45,'0원')

# %%
print(len(title_list))
print(len(dump_list))
print(len(url_list))
print(len(teacher_list))

# %%
print(len(class101_num_list))
print(len(class101_review_list))
print(len(class101_cate_list))
